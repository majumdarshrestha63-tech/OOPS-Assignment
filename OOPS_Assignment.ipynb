# %% [markdown]
# Answers of Theory Questions
#
# 1. Object-Oriented Programming (OOP) is a programming paradigm (style of programming) that is based on the concept of objects which combines data (attributes) and behavior (methods) into a single unit. It helps to organize code in a way that is more modular, reusable, and easier to maintain.
#
# 2. Classes are blueprint/template for creating an object. We are different objects of class human beings.
#
# 3. An object is a real-world entity or an instance of a class that contains both data (attributes) and behaviors (methods).
#
# 4. The concept of hiding complex implementation is known as Abstraction.
# The bundling of data and methods of a class is known as Encapsulation.
#
# 5. Dunder/Magic/ Special methods are the methods defined by built- in classes in python. These methods are defined type of methods for creating custom objects/ implementing overloading in python. Dunder means- d+under= double underscore- all the methods surrounding double underscore is a dunder method.
#
# 6. Inheritance is a fundamental concept that allows one class (called the child or subclass) to acquire the properties and behaviors (methods and attributes) of another class (called the parent or base class). It promotes code reusability, extensibility, and helps create a clear class hierarchy.
#
# 7.  Polymorphism- poly means many and morphism means forms/states- refers to an object taking several forms depending on the methods/ data.
#
# 8.  Python does not have strict access modifiers like private or protected (as in Java or C++), but it follows naming conventions to indicate access level:
#
#    Public Members- Accessible from anywhere
#
#    Protected Members (Convention) - Prefix with a single underscore _ to indicate “internal use only”.
#
#    Private Members- Prefix with two underscores __ — Python performs name mangling, making them harder to access directly.
#
# 9.  A constructor is a special method that is automatically called when a new object of a class is created. It is mainly used to initialize (set up) the object’s attributes with initial values.
#
# 10.  Class methods are bound to the class that  access / modify methods and attributes associated to the class. @classmethod decorator instead of self, class(not to a particular instance of the class, instead of self, class as first parameter).Static method does not modify class or instance state, access instance or class state, and not depend on class/instance. It behaves like a plain function that belongs to class, it does not take either self or class. @staticmethod is used.
#
# 11. Method overloading- student method is taking different forms, the last method overloads the previous ones in the same class.
#
# 12. Method Overriding- Method in parent class and child class with same signature, the child class method will be executed as well.
#
#
# 13. Property decorators are allowed to use class method as an attribute.
#
#
# 14. Polymorphism is important because it promotes flexibility, enables code reuse, simplifies maintenance and scalability and supports abstraction and clean architecture.
#
#
# 15. An abstract class is a class that cannot be instantiated directly, it serves as a blueprint for other classes. It defines abstract methods that must be implemented by any subclass.
#
#
# 16. The advantages of OOP are as follows:-
#
#     Modularity- Code is organized into manageable sections
#
#     Reusability- Existing code can be reused via inheritance
#
#     Encapsulation - Protects data and ensures controlled access
#
#     Polymorphism - Enables flexibility through method overriding
#
#     Abstraction - Simplifies interaction by hiding details
#
#     Maintainability - Easier debugging and updates
#
#     Scalability- Supports growth and new features easily
#
# 17. Class Variable- Belongs to the class itself, not to any specific object (instance), shared by all instances of the class and defined inside the class, but outside any method.
#   Instance Variable- Belongs to a specific instance (object) of the class, each object has its own copy of instance variables and usually defined inside the __init__() method using self.
#
# 18. One child class may inherit the property of multiple parent class is known as Multiple Inheritence.
#
# 19. __str__() — User-Friendly Representation
#
#     The __str__() method is meant to return a human-readable or user-friendly description of an object.
#
#     It is called when we use the print() function or str() on an object.
#
#     __repr__() — Developer / Debug Representation
#
#     The __repr__() method is meant to return a detailed or unambiguous string representation of an object.
#
#     It is mainly for developers and debugging.
#
#     It should ideally return a string that could recreate the object if passed to eval().
#
# 20. The super() function in Python is used to call a method from the parent (or superclass) inside a subclass. It helps to ensure that the base class  behavior is properly executed without directly referring to its name.
#
# 21. The __del__() method in Python is known as a destructor. It is automatically called when an object is about to be destroyed that is, when it's no longer needed and Python's garbage collector is reclaiming its memory.
#
# 22. @staticmethod- A static method is a method that does not depend on the class or instance.It behaves just like a regular function but belongs to the class's namespace.
#    @classmethod- A class method is a method that works on the class itself, not on instances.It receives the class (cls) as the first argument.
#
# 23. When a child class (subclass) inherits from a parent class (superclass),it can override the parent's methods with its own version, then when we call that method on a subclass object, python automatically uses the child's version. This is runtime polymorphism.
#
# 24. Method chaining works when each method returns the object itself (usually self).That way,we can keep calling other methods on the same object.
#
# 25. In Python, the __call__() method allows an object to be called like a function.It's one of Python's special (dunder) methods, and it gives objects function-like behavior while still maintaining state and class structure.
#
#    Defination- The __call__() method is automatically invoked when we use parentheses () after an object. In simple terms if a class defines a __call__() method, its instances can be called like functions.

# %% [markdown]
# Answers of Practical Questions
#
# 1.

# %%
# Parent class
class Animal:
    def speak(self):
        print("The animal makes a sound")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Create objects
a = Animal()
a.speak()   # Output: The animal makes a sound

d = Dog()
d.speak()   # Output: Bark!

# %% [markdown]
# 2.

# %%
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass  # Abstract method (no implementation)

# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Create objects
circle = Circle(5)
rectangle = Rectangle(4, 6)

# Display results
print("Area of Circle:", circle.area())
print("Area of Rectangle:", rectangle.area())

# %% [markdown]
# 3.

# %%
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def show_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Derived class from Vehicle
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print(f"Car Brand: {self.brand}")

# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def show_details(self):
        self.show_type()
        self.show_brand()
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Create object of ElectricCar
e_car = ElectricCar("Four-wheeler", "Tesla", 75)

# Display details
e_car.show_details()

# %% [markdown]
# 4.

# %%
# Base class
class Bird:
    def fly(self):
        print("Some birds can fly, some cannot.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high in the sky!")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead!")

# Function demonstrating polymorphism
def bird_fly_test(bird):
    bird.fly()

# Create objects
sparrow = Sparrow()
penguin = Penguin()

# Polymorphism in action
bird_fly_test(sparrow)   # Output: Sparrow can fly high in the sky!
bird_fly_test(penguin)   # Output: Penguins cannot fly, they swim instead!

# %% [markdown]
# 5.

# %%
# Class demonstrating encapsulation
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance   # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Deposit amount must be positive!")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ₹{amount}")
        else:
            print("Invalid withdrawal amount or insufficient balance!")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: ₹{self.__balance}")

# Create object
account = BankAccount(5000)

# Access through methods (not directly)
account.deposit(1500)
account.withdraw(2000)
account.check_balance()

# %% [markdown]
# 6.

# %%
# Base class
class Instrument:
    def play(self):
        print("Playing some instrument sound.")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar!")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Playing the piano keys!")

# Function demonstrating runtime polymorphism
def perform(instrument):
    instrument.play()

# Create objects
guitar = Guitar()
piano = Piano()

# Polymorphism in action
perform(guitar)   # Output: Strumming the guitar!
perform(piano)    # Output: Playing the piano keys!

# %% [markdown]
# 7.

# %%
class MathOperations:
    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Using class method
sum_result = MathOperations.add_numbers(10, 5)
print("Sum:", sum_result)

# Using static method
difference = MathOperations.subtract_numbers(10, 5)
print("Difference:", difference)
Sum: 15
Difference: 5

# %% [markdown]
# 8.

# %%
class Person:
    # Class variable to count number of persons
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1   # Increment count whenever a new object is created

    # Class method to get total count
    @classmethod
    def get_person_count(cls):
        return cls.count

# Create Person objects
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

# Display total number of persons created
print("Total persons created:", Person.get_person_count())
Total persons created: 3

# %% [markdown]
# 9.

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Override __str__ method
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Create Fraction objects
f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

# Display fractions
print(f1)   # Output: 3/4
print(f2)   # Output: 5/8

# %% [markdown]
# 10.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overload the '+' operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # For displaying the vector nicely
    def __str__(self):
        return f"({self.x}, {self.y})"

# Create Vector objects
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Add vectors using '+' operator
result = v1 + v2

# Display result
print("Vector 1:", v1)
print("Vector 2:", v2)
print("Sum of Vectors:", result)
Vector 1: (2, 3)
Vector 2: (4, 5)
Sum of Vectors: (6, 8)

# %% [markdown]
# 11.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Create an object of Person
p1 = Person("Shrestha", 27)

# Call the greet method
p1.greet()
Hello, my name is Shrestha and I am 27 years old

# %% [markdown]
# 12.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # Expecting a list of numbers

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# Create a Student object
student1 = Student("John", [85, 90, 78, 92, 88])

# Display results
print(f"Student Name: {student1.name}")
print(f"Grades: {student1.grades}")
print(f"Average Grade: {student1.average_grade():.2f}")
Student Name: John
Grades: [85, 90, 78, 92, 88]
Average Grade: 86.60

# %% [markdown]
# 13.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set dimensions
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate area
    def area(self):
        return self.length * self.width

# Create an object of Rectangle
rect = Rectangle()

# Set dimensions
rect.set_dimensions(10, 5)

# Display the area
print(f"Length: {rect.length}")
print(f"Width: {rect.width}")
print(f"Area of Rectangle: {rect.area()}")
Length: 10
Width: 5
Area of Rectangle: 50

# %% [markdown]
# 14.

# %%
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    # Method to calculate salary
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)  # Call parent constructor
        self.bonus = bonus

    # Override method to include bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Create objects
emp = Employee("John", 40, 25)
mgr = Manager("Alice", 45, 30, 500)

# Display results
print(f"Employee: {emp.name}, Salary: ₹{emp.calculate_salary()}")
print(f"Manager: {mgr.name}, Salary (with bonus): ₹{mgr.calculate_salary()}")
Employee: John, Salary: ₹1000
Manager: Alice, Salary (with bonus): ₹1850

# %% [markdown]
# 15.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity

# Create Product objects
p1 = Product("Laptop", 60000, 2)
p2 = Product("Mouse", 800, 5)

# Display total prices
print(f"Product: {p1.name}, Total Price: ₹{p1.total_price()}")
print(f"Product: {p2.name}, Total Price: ₹{p2.total_price()}")
Product: Laptop, Total Price: ₹120000
Product: Mouse, Total Price: ₹4000

# %% [markdown]
# 16.

# %%
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass  # Abstract method

# Derived class Cow
class Cow(Animal):
    def sound(self):
        print("Cow says: Moo!")

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa!")

# Create objects
cow = Cow()
sheep = Sheep()

# Call the sound method
cow.sound()    # Output: Cow says: Moo!
sheep.sound()  # Output: Sheep says: Baa!

# %% [markdown]
# 17.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return formatted book information
    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# Create a Book object
book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)

# Display book information
print(book1.get_book_info())
Title: To Kill a Mockingbird, Author: Harper Lee, Year Published: 1960

# %% [markdown]
# 18.

# %%
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def show_info(self):
        print(f"Address: {self.address}")
        print(f"Price: ₹{self.price}")

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)  # Call base class constructor
        self.number_of_rooms = number_of_rooms

    def show_mansion_info(self):
        self.show_info()
        print(f"Number of Rooms: {self.number_of_rooms}")

# Create objects
house = House("123 Main St", 5000000)
mansion = Mansion("456 Luxury Ave", 25000000, 10)

# Display information
print("House Info:")
house.show_info()

print("\nMansion Info:")
mansion.show_mansion_info()
House Info:
Address: 123 Main St
Price: ₹5000000

Mansion Info:
Address: 456 Luxury Ave
Price: ₹25000000
Number of Rooms: 10
